# %%
# !pip install ollama
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ollama
#   Using cached ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: httpx>=0.27 in c:\programdata\anaconda3\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\programdata\anaconda3\lib\site-packages (from ollama) (2.12.4)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (4.10.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.9->ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)
# Using cached ollama-0.6.2-py3-none-any.whl (15 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.2

# %%
import ollama

response = ollama.chat(
    model='gemma4:cloud',
    messages=[{'role': 'user', 'content': 'What is the risk level of IP 192.168.1.50?'}],
    tools=[{
        'type': 'function',
        'function': {
            'name': 'get_ip_details',
            'description': 'Get reputation and details for an IP address',
            'parameters': {
                'type': 'object',
                'properties': {
                    'ip_address': {'type': 'string', 'description': 'The IP address to look up'}
                },
                'required': ['ip_address']
            }
        }
    }]
)

print(response['message'])
# Out:
# role='assistant' content='' thinking=None images=None tool_name=None tool_calls=[ToolCall(function=Function(name='get_ip_details', arguments={'ip_address': '192.168.1.50'}))]
